# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

plt.style.use('classic')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRB24            CHUKWUDI017              DRB24_CHUKWUDI017
# 1              FDR31            CHUKWUDI019              FDR31_CHUKWUDI019
# 2              FDP16            CHUKWUDI017              FDP16_CHUKWUDI017
# 3              FDY16            CHUKWUDI027              FDY16_CHUKWUDI027
# 4              FDY48            CHUKWUDI046              FDY48_CHUKWUDI046
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility  \
# 0           8.785             Low Fat                  0.020694
# 1             NaN          Normal Fat                  0.086078
# 2          18.600             Low Fat                  0.039517
# 3             NaN          Normal Fat                  0.091780
# 4          14.000             Low Fat                  0.023735
#
#             Product_Type  Product_Price  Supermarket_Opening_Year  \
# ...

# %%
test_data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              FDC15            CHUKWUDI049              FDC15_CHUKWUDI049
# 1              NCY06            CHUKWUDI018              NCY06_CHUKWUDI018
# 2              DRB24            CHUKWUDI035              DRB24_CHUKWUDI035
# 3              NCG54            CHUKWUDI018              NCG54_CHUKWUDI018
# 4              NCA42            CHUKWUDI017              NCA42_CHUKWUDI017
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0          18.100             Low Fat                  0.178246        Dairy
# 1          15.250             Low Fat                  0.061434    Household
# 2           8.785             Low Fat                  0.020573  Soft Drinks
# 3          12.100             Low Fat                  0.080131    Household
# 4           6.965             Low Fat                  0.028710    Household
#
# ...

# %%
train_data.shape
# Out:
# (3742, 13)

# %%
train_data.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                     601
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1126
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Product_Identifier                  0
# Supermarket_Identifier              0
# Product_Supermarket_Identifier      0
# Product_Weight                    201
# Product_Fat_Content                 0
# Product_Shelf_Visibility            0
# Product_Type                        0
# Product_Price                       0
# Supermarket_Opening_Year            0
# Supermarket _Size                 324
# Supermarket_Location_Type           0
# Supermarket_Type                    0
# dtype: int64

# %%
test_data.shape
# Out:
# (1248, 12)

# %%
train_data.drop(['Product_Identifier','Supermarket_Identifier'],axis=1,inplace=True)
test_data.drop(['Product_Identifier','Supermarket_Identifier'],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#   Product_Supermarket_Identifier  Product_Weight Product_Fat_Content  \
# 0              DRB24_CHUKWUDI017           8.785             Low Fat
# 1              FDR31_CHUKWUDI019             NaN          Normal Fat
# 2              FDP16_CHUKWUDI017          18.600             Low Fat
# 3              FDY16_CHUKWUDI027             NaN          Normal Fat
# 4              FDY48_CHUKWUDI046          14.000             Low Fat
#
#    Product_Shelf_Visibility           Product_Type  Product_Price  \
# 0                  0.020694            Soft Drinks         382.91
# 1                  0.086078  Fruits and Vegetables         359.53
# 2                  0.039517           Frozen Foods         609.20
# 3                  0.091780           Frozen Foods         456.32
# 4                  0.023735           Baking Goods         258.08
#
#    Supermarket_Opening_Year Supermarket _Size Supermarket_Location_Type  \
# 0                      2014               NaN                 Cluster 2
# ...

# %%
test_data.head()
# Out:
#   Product_Supermarket_Identifier  Product_Weight Product_Fat_Content  \
# 0              FDC15_CHUKWUDI049          18.100             Low Fat
# 1              NCY06_CHUKWUDI018          15.250             Low Fat
# 2              DRB24_CHUKWUDI035           8.785             Low Fat
# 3              NCG54_CHUKWUDI018          12.100             Low Fat
# 4              NCA42_CHUKWUDI017           6.965             Low Fat
#
#    Product_Shelf_Visibility Product_Type  Product_Price  \
# 0                  0.178246        Dairy         395.32
# 1                  0.061434    Household         327.49
# 2                  0.020573  Soft Drinks         391.16
# 3                  0.080131    Household         427.28
# 4                  0.028710    Household         395.40
#
#    Supermarket_Opening_Year Supermarket _Size Supermarket_Location_Type  \
# 0                      2006            Medium                 Cluster 1
# ...

# %%
train_data.shape, test_data.shape
# Out:
# ((3742, 11), (1248, 10))

# %%
train_data['Product_Supermarket_Sales'].value_counts()
# Out:
# 3355.63     8
# 3076.00     8
# 4673.92     8
# 4738.83     7
# 4613.99     7
#            ..
# 10736.03    1
# 4389.29     1
# 10835.90    1
# 2267.05     1
# 253.00      1
# Name: Product_Supermarket_Sales, Length: 2293, dtype: int64

# %%
train_data['Product_Fat_Content'].value_counts()
# Out:
# Low Fat          2272
# Normal Fat       1341
# Ultra Low fat     129
# Name: Product_Fat_Content, dtype: int64

# %%
train_data['Product_Type'].value_counts()
# Out:
# Snack Foods              563
# Fruits and Vegetables    556
# Household                414
# Frozen Foods             334
# Canned                   294
# Dairy                    263
# Baking Goods             259
# Health and Hygiene       222
# Meat                     202
# Soft Drinks              193
# Breads                   115
# Hard Drinks               97
# Others                    82
# Starchy Foods             62
# Breakfast                 54
# Seafood                   32
# Name: Product_Type, dtype: int64

# %%
train_data['Supermarket_Opening_Year'].value_counts()
# Out:
# 1992    601
# 2014    461
# 2006    451
# 1994    446
# 2004    388
# 2009    377
# 2011    372
# 2016    358
# 2005    288
# Name: Supermarket_Opening_Year, dtype: int64

# %%
train_data['Supermarket _Size'].value_counts()
# Out:
# Medium    1155
# Small     1015
# High       446
# Name: Supermarket _Size, dtype: int64

# %%
train_data['Supermarket _Size'].nunique()
# Out:
# 3

# %%
train_data.isnull().sum()
# Out:
# Product_Supermarket_Identifier       0
# Product_Weight                     601
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1126
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
train_data.Product_Weight.isnull().any()
# Out:
# True

# %%
train_data.shape
# Out:
# (3742, 11)

# %%
train_data['Product_Weight'].values
# Out:
# array([ 8.785,    nan, 18.6  , ...,  8.31 , 17.   ,  9.   ])

# %%
train_data['Product_Weight'] = train_data['Product_Weight'].fillna(train_data['Product_Weight'].mean())
test_data['Product_Weight'] = test_data['Product_Weight'].fillna(test_data['Product_Weight'].mean())

# %%
train_data.isnull().sum()
# Out:
# Product_Supermarket_Identifier       0
# Product_Weight                       0
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1126
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
train_data['Supermarket _Size'].value_counts()
# Out:
# Medium    1155
# Small     1015
# High       446
# Name: Supermarket _Size, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='Unknown')

# %%
train_data['Supermarket _Size'] = imp.fit_transform(train_data[['Supermarket _Size']])

test_data['Supermarket _Size'] = imp.fit_transform(test_data[['Supermarket _Size']])

# %%
train_data.isnull().sum()
# Out:
# Product_Supermarket_Identifier    0
# Product_Weight                    0
# Product_Fat_Content               0
# Product_Shelf_Visibility          0
# Product_Type                      0
# Product_Price                     0
# Supermarket_Opening_Year          0
# Supermarket _Size                 0
# Supermarket_Location_Type         0
# Supermarket_Type                  0
# Product_Supermarket_Sales         0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Product_Supermarket_Identifier    0
# Product_Weight                    0
# Product_Fat_Content               0
# Product_Shelf_Visibility          0
# Product_Type                      0
# Product_Price                     0
# Supermarket_Opening_Year          0
# Supermarket _Size                 0
# Supermarket_Location_Type         0
# Supermarket_Type                  0
# dtype: int64

# %%
train_data.head()
# Out:
#   Product_Supermarket_Identifier  Product_Weight Product_Fat_Content  \
# 0              DRB24_CHUKWUDI017         8.78500             Low Fat
# 1              FDR31_CHUKWUDI019        12.87064          Normal Fat
# 2              FDP16_CHUKWUDI017        18.60000             Low Fat
# 3              FDY16_CHUKWUDI027        12.87064          Normal Fat
# 4              FDY48_CHUKWUDI046        14.00000             Low Fat
#
#    Product_Shelf_Visibility           Product_Type  Product_Price  \
# 0                  0.020694            Soft Drinks         382.91
# 1                  0.086078  Fruits and Vegetables         359.53
# 2                  0.039517           Frozen Foods         609.20
# 3                  0.091780           Frozen Foods         456.32
# 4                  0.023735           Baking Goods         258.08
#
#    Supermarket_Opening_Year Supermarket _Size Supermarket_Location_Type  \
# 0                      2014           Unknown                 Cluster 2
# ...

# %%
train_data['Supermarket_Type'].value_counts()
# Out:
# Supermarket Type1    2495
# Grocery Store         543
# Supermarket Type2     358
# Supermarket Type3     346
# Name: Supermarket_Type, dtype: int64

# %%
train_data['Supermarket _Size'].value_counts()
# Out:
# Medium     1155
# Unknown    1126
# Small      1015
# High        446
# Name: Supermarket _Size, dtype: int64

# %%
train_data['Supermarket_Location_Type'].value_counts()
# Out:
# Cluster 3    1438
# Cluster 2    1210
# Cluster 1    1094
# Name: Supermarket_Location_Type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
train_data['Product_Fat_Content'] = le.fit_transform(train_data[['Product_Fat_Content']])
train_data['Supermarket _Size'] = le.fit_transform(train_data[['Supermarket _Size']])
test_data['Product_Fat_Content'] = le.fit_transform(test_data[['Product_Fat_Content']])
test_data['Supermarket _Size'] = le.fit_transform(test_data[['Supermarket _Size']])

prod_type = pd.get_dummies(train_data.Product_Type)
sup_lo = pd.get_dummies(train_data.Supermarket_Location_Type)
sup_type = pd.get_dummies(train_data.Supermarket_Type)
prod_type1 = pd.get_dummies(test_data.Product_Type)
sup_lo1 = pd.get_dummies(test_data.Supermarket_Location_Type)
sup_type1 = pd.get_dummies(test_data.Supermarket_Type)

train_data = pd.concat([train_data, prod_type, sup_lo, sup_type ], axis = 1)
test_data = pd.concat([test_data, prod_type1, sup_lo1, sup_type1 ], axis = 1)

# %%
train_data = train_data.drop(['Product_Type', 'Supermarket_Location_Type', 'Supermarket_Type'], axis = 1)
test_data = test_data.drop(['Product_Type', 'Supermarket_Location_Type', 'Supermarket_Type'], axis = 1)

# %%
train_data.head()
# Out:
#   Product_Supermarket_Identifier  Product_Weight  Product_Fat_Content  \
# 0              DRB24_CHUKWUDI017         8.78500                    0
# 1              FDR31_CHUKWUDI019        12.87064                    1
# 2              FDP16_CHUKWUDI017        18.60000                    0
# 3              FDY16_CHUKWUDI027        12.87064                    1
# 4              FDY48_CHUKWUDI046        14.00000                    0
#
#    Product_Shelf_Visibility  Product_Price  Supermarket_Opening_Year  \
# 0                  0.020694         382.91                      2014
# 1                  0.086078         359.53                      1992
# 2                  0.039517         609.20                      2014
# 3                  0.091780         456.32                      1992
# 4                  0.023735         258.08                      2004
#
#    Supermarket _Size  Product_Supermarket_Sales  Baking Goods  Breads  ...  \
# ...

# %%
test_data.head()
# Out:
#   Product_Supermarket_Identifier  Product_Weight  Product_Fat_Content  \
# 0              FDC15_CHUKWUDI049          18.100                    0
# 1              NCY06_CHUKWUDI018          15.250                    0
# 2              DRB24_CHUKWUDI035           8.785                    0
# 3              NCG54_CHUKWUDI018          12.100                    0
# 4              NCA42_CHUKWUDI017           6.965                    0
#
#    Product_Shelf_Visibility  Product_Price  Supermarket_Opening_Year  \
# 0                  0.178246         395.32                      2006
# 1                  0.061434         327.49                      2016
# 2                  0.020573         391.16                      2011
# 3                  0.080131         427.28                      2016
# 4                  0.028710         395.40                      2014
#
#    Supermarket _Size  Baking Goods  Breads  Breakfast  ...  Snack Foods  \
# ...

# %%
new_test_data = test_data.drop(['Product_Supermarket_Identifier'], axis = 1)
new_train_data = train_data.drop(['Product_Supermarket_Identifier'], axis = 1)

# %%
y = new_train_data['Product_Supermarket_Sales']
X = new_train_data.drop([ 'Product_Supermarket_Sales'], axis = 1)

# %%
X.shape, new_test_data.shape
# Out:
# ((3742, 29), (1248, 29))

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((2993, 29), (2993,))

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import Ridge
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
from catboost import CatBoostRegressor
import xgboost as xgb
from sklearn.tree import DecisionTreeRegressor
from sklearn import linear_model
linear_model.Lasso(alpha=0.1)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
pipe = Pipeline([("scaler", StandardScaler()), ("regressor", LinearRegression())])
pipe.fit(X_train, y_train)

score = pipe.score(X_test, y_test)
score
# Out:
# 0.5469431560550535

# %%
pred = pipe.predict(X_test)

# %%
mean_squared_error(y_test,pred)**(0.5)
# Out:
# 3095.601347519493

# %%
test_data_pred = test_data.drop(['Product_Supermarket_Identifier'], axis = 1)

# %%
test_pred = pipe.predict(test_data_pred)

# %%
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}

# %%
subm = pd.DataFrame(dicts)

# %%
subm.to_csv('3rd.csv', index = False)

# %%
CatBoostRegressor?

# %%
pipe1 = Pipeline([("scaler", StandardScaler()), ("regressor", CatBoostRegressor(depth = 3))])
pipe1.fit(X_train, y_train)

score1 = pipe1.score(X_test, y_test)
# Out:
# Learning rate set to 0.04744
# 0:	learn: 4315.6849594	total: 1.7ms	remaining: 1.69s
# 1:	learn: 4217.7709869	total: 3.43ms	remaining: 1.71s
# 2:	learn: 4139.1444141	total: 4.9ms	remaining: 1.63s
# 3:	learn: 4056.4097440	total: 6.5ms	remaining: 1.62s
# 4:	learn: 3976.1647882	total: 7.99ms	remaining: 1.59s
# 5:	learn: 3901.1179817	total: 9.54ms	remaining: 1.58s
# 6:	learn: 3832.0107853	total: 11ms	remaining: 1.57s
# 7:	learn: 3768.0410401	total: 12.5ms	remaining: 1.55s
# 8:	learn: 3708.6017593	total: 14.1ms	remaining: 1.55s
# 9:	learn: 3659.8992013	total: 15.4ms	remaining: 1.53s
# 10:	learn: 3614.9723141	total: 17ms	remaining: 1.52s
# 11:	learn: 3566.8217150	total: 18.4ms	remaining: 1.52s
# 12:	learn: 3520.7312306	total: 19.9ms	remaining: 1.51s
# 13:	learn: 3478.0695836	total: 21.5ms	remaining: 1.52s
# 14:	learn: 3438.4755520	total: 23.1ms	remaining: 1.51s
# 15:	learn: 3403.4160717	total: 24.4ms	remaining: 1.5s
# 16:	learn: 3368.7667519	total: 25.9ms	remaining: 1.5s
# ...

# %%
pred1 = pipe1.predict(X_test)

# %%
mean_squared_error(y_test,pred1)**(0.5)
# Out:
# 3027.6208690074413

# %%
test_pred = pipe1.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('11th.csv', index = False)

# %%
pipe2 = Pipeline([("scaler", StandardScaler()), ("regressor", xgb.XGBRegressor())])
pipe2.fit(X_train, y_train)

score2 = pipe2.score(X_test, y_test)

# %%
xgb.XGBRegressor?

# %%
preds = pipe2.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 3250.231157

# %%
test_pred = pipe2.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('6th.csv', index = False)

# %%
pipe3 = Pipeline([("scaler", StandardScaler()), ("regressor", DecisionTreeRegressor(max_depth = 5, min_samples_split = 100))])
pipe3.fit(X_train, y_train)

score = pipe3.score(X_test, y_test)
score

preds = pipe3.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 3049.621927

# %%
test_pred = pipe3.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('15th.csv', index = False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.metrics import mean_squared_error as mse

model = tree.DecisionTreeRegressor()

gs = GridSearchCV(model,
                  {'max_depth': range(1, 15),
                  'min_samples_split': range(10, 110, 10)},
                  cv=5,
                  n_jobs=2,
                  scoring='neg_mean_squared_error')

gs.fit(X_train, y_train)

print(gs.best_params_)
# Out:
# {'max_depth': 5, 'min_samples_split': 100}

# %%
model = gs.best_estimator_
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=100,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
print((mse(y_test, model.predict(X_test)))**0.5)
# Out:
# 3049.621927382086

# %%
test_pred = model.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('16th.csv', index = False)

# %%
from sklearn.neighbors import KNeighborsRegressor

tree_reg = tree.DecisionTreeRegressor()
knn_reg = KNeighborsRegressor()

estimators = {'tree_reg': tree_reg, 'knn_reg': knn_reg}
hyperparam_dict = {'tree_reg': {'min_samples_split': range(10, 110, 10), 'max_depth': range(1, 15)}, 'knn_reg': {'n_neighbors': range(10, 100, 10)}}

scores = {}
for name, estimator in estimators.items():
    gs = GridSearchCV(estimator,
                      hyperparam_dict[name],
                      cv=5,
                      n_jobs=2,
                      scoring='neg_mean_squared_error')
    
    gs.fit(X_train, y_train)

    scores[name] = -gs.best_score_

print(scores)
# Out:
# {'tree_reg': 8625285.12481077, 'knn_reg': 14011203.1451152}

# %%
model = KNeighborsRegressor()

gs = GridSearchCV(model,
                  {'n_neighbors': range(10, 100, 10)},
                  cv=5,
                  n_jobs=2,
                  scoring='neg_mean_squared_error')

gs.fit(X_train, y_train)

print(gs.best_params_)
# Out:
# {'n_neighbors': 90}

# %%
model = gs.best_estimator_
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=90, p=2,
#                     weights='uniform')

# %%
print((mse(y_test, model.predict(X_test)))**0.5)
# Out:
# 3955.2367308950893

# %%
test_pred = model.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('17th.csv', index = False)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor,AdaBoostRegressor, ExtraTreesRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeRegressor





seed = 7
models = []
models.append(('Lr', LinearRegression()))
models.append(('LDA', RandomForestRegressor()))
models.append(('gbm', GradientBoostingRegressor()))
models.append(('Decision_Tree', DecisionTreeRegressor()))
models.append(('Adb', AdaBoostRegressor()))
models.append(('Extra_Tree', ExtraTreesRegressor()))
models.append(('xgb', XGBRegressor(n_estimators = 50)))
models.append(('Catboost', CatBoostRegressor(silent = True)))

# evaluate each model in turn
results = []
names = []
for name, model in models:
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    rmse = (mse(y_test, model.predict(X_test)))**0.5
    results.append(score)
    names.append(name)
    msg = "%s: %f " % (name, rmse)
    print(msg)
# Out:
# Lr: 3095.557658
# LDA: 3125.408206
# gbm: 3039.857284
# Decision_Tree: 4140.221135
# Adb: 3469.114848
# Extra_Tree: 3269.895799
# xgb: 3075.176954
# Catboost: 3084.363924

# %%
model1 = GradientBoostingRegressor(max_depth = 4, random_state = 10, min_samples_leaf = 45, min_samples_split = 50,
                                   learning_rate = 0.1, subsample = 1.0)
model1.fit(X_train, y_train)
pred = model1.predict(X_test)

# %%
print((mse(y_test, model1.predict(X_test)))**0.5)
# Out:
# 2996.798942755086

# %%
test_pred = model1.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('21st.csv', index = False)

# %%
    # load libraries
from sklearn import decomposition, datasets
from sklearn import tree
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler


# Create an scaler object
sc = StandardScaler()

# Create a pca object
pca = decomposition.PCA()

# Create a logistic regression object with an L2 penalty
decisiontree = tree.DecisionTreeRegressor()

# Create a pipeline of three steps. First, standardize the data.
# Second, tranform the data with PCA.
# Third, train a Decision Tree Classifier on the data.
pipe = Pipeline(steps=[('sc', sc),
                       ('pca', pca),
                       ('decisiontree', decisiontree)])

# Create Parameter Space
# Create a list of a sequence of integers from 1 to 30 (the number of features in X + 1)
n_components = list(range(1,X.shape[1]+1,1))

# Create lists of parameter for Decision Tree Classifier

max_depth = [4,6,8,12]

# Create a dictionary of all the parameter options 
# Note has you can access the parameters of steps of a pipeline by using '__’
parameters = dict(pca__n_components=n_components,
                
                  decisiontree__max_depth=max_depth)

# Conduct Parameter Optmization With Pipeline
# Create a grid search object
clf = GridSearchCV(pipe, parameters)

# Fit the grid search
clf.fit(X_train, y_train)

# View The Best Parameters
print('Best max_depth:', clf.best_estimator_.get_params()['decisiontree__max_depth'])
print('Best Number Of Components:', clf.best_estimator_.get_params()['pca__n_components'])
print(); print(clf.best_estimator_.get_params()['decisiontree'])

# Use Cross Validation To Evaluate Model
CV_Result = cross_val_score(clf, X, y, cv=4, n_jobs=-1)
print(); print(CV_Result)
print(); print(CV_Result.mean())
print(); print(CV_Result.std())
# Out:
# Best max_depth: 4
# Best Number Of Components: 27
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=4,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
#
# [0.50603812 0.48413475 0.47977054 0.48920339]
#
# 0.4897866997786962
#
# 0.009958874597984632

# %%
test_pred = clf.predict(test_data_pred)
dicts = {'Product_Supermarket_Identifier' : test_data['Product_Supermarket_Identifier'], 'Product_Supermarket_Sales':
        test_pred}
subm = pd.DataFrame(dicts)
subm.to_csv('t.csv', index = False)
